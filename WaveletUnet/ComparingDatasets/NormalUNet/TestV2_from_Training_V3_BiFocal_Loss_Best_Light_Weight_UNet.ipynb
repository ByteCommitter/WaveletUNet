#   inflating: dataset/V3/Images/scene00099.jpeg
#   inflating: dataset/V3/Images/scene00100.jpeg
#   inflating: dataset/V3/Images/scene00101.jpeg
#   inflating: dataset/V3/Images/scene00102.jpeg
#   inflating: dataset/V3/Images/scene00103.jpeg
#   inflating: dataset/V3/Images/scene00104.jpeg
#   inflating: dataset/V3/Images/scene00106.jpeg
#   inflating: dataset/V3/Images/scene00107.jpeg
#   inflating: dataset/V3/Images/scene00108.jpeg
#   inflating: dataset/V3/Images/scene00109.jpeg
#   inflating: dataset/V3/Images/scene00110.jpeg
#   inflating: dataset/V3/Images/scene00111.jpeg
#   inflating: dataset/V3/Images/scene00112.jpeg
#   inflating: dataset/V3/Images/scene00113.jpeg
#   inflating: dataset/V3/Images/scene00114.jpeg
#   inflating: dataset/V3/Images/scene00115.jpeg
#   inflating: dataset/V3/Images/scene00116.jpeg
#   inflating: dataset/V3/Images/scene00117.jpeg
#   inflating: dataset/V3/Images/scene00118.jpeg
#   inflating: dataset/V3/Images/scene00119.jpeg
#   inflating: dataset/V3/Images/scene00121.jpeg
#   inflating: dataset/V3/Images/scene00122.jpeg
#   inflating: dataset/V3/Images/scene00123.jpeg
#   inflating: dataset/V3/Images/scene00124.jpeg
#   inflating: dataset/V3/Images/scene00125.jpeg
#   inflating: dataset/V3/Images/scene00126.jpeg
#   inflating: dataset/V3/Images/scene00127.jpeg
#   inflating: dataset/V3/Images/scene00128.jpeg
#   inflating: dataset/V3/Images/scene00129.jpeg
#   inflating: dataset/V3/Images/scene00130.jpeg

# %%
#convert all the segmented images into black and white
import cv2
import os
import numpy as np

def convert_annotations(input_folder, output_folder):
    """
    Convert pink annotations to binary (black and white) masks
    """
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Process each image in the folder
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Read image
            img_path = os.path.join(input_folder, filename)
            img = cv2.imread(img_path)

            # Convert to binary mask
            # Convert to grayscale first
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Threshold to create binary image
            # Assuming pink regions are significantly different from black background
            _, binary = cv2.threshold(gray, 10, 255, cv2.THRESH_BINARY)

            # Save the binary mask
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, binary)

# Usage
input_folder = "/content/dataset/V2/Annotations"
output_folder = "/content/dataset/V2/AnnotationsWB"
convert_annotations(input_folder, output_folder)

# %%
# Usage
input_folder = "/content/dataset/V3/Annotations"
output_folder = "/content/dataset/V3/AnnotationsWB"
convert_annotations(input_folder, output_folder)

# %%
import os
import shutil
import random

# Assuming the previous code has already been executed, and the following directories are set up:
IMAGE_PATH = '/content/dataset/V3/Images/'
MASK_PATH = '/content/dataset/V3/AnnotationsWB'
TEST_PATH = '/content/dataset/V2/Images'

# Check the number of files in the test directory
print("Number of files in the test directory: " + str(len(os.listdir(TEST_PATH))))
# Out:
# Number of files in the test directory: 128

# %%
# # Create the test_masks directory if it doesn't exist
TEST_MASKS_PATH = '/content/dataset/V2/AnnotationsWB'
# os.makedirs(TEST_MASKS_PATH, exist_ok=True)

# %%
print("Number of files in the mask directory: " + str(len(os.listdir(MASK_PATH))))
print("Number of files in the train_image directory: " + str(len(os.listdir(IMAGE_PATH))))
# Out:
# Number of files in the mask directory: 127
# Number of files in the train_image directory: 127

# %%
print("Number of files in the mask directory: " + str(len(os.listdir(TEST_PATH))))
print("Number of files in the train_image directory: " + str(len(os.listdir(TEST_MASKS_PATH))))
# Out:
# Number of files in the mask directory: 128
# Number of files in the train_image directory: 128

# %%
import os
from PIL import Image

# Define paths
jpeg_folder = "/content/dataset/V2/Images/"  # Replace with your folder containing .jpeg files
png_folder = "/content/dataset/V2/Imagespng"   # Replace with your desired output folder for .png files

# Create output folder if it doesn't exist
os.makedirs(png_folder, exist_ok=True)

# Loop through all files in the .jpeg folder
for file_name in os.listdir(jpeg_folder):
    if file_name.endswith(".jpeg") or file_name.endswith(".jpg"):
        # Open the .jpeg file
        jpeg_path = os.path.join(jpeg_folder, file_name)
        image = Image.open(jpeg_path)

        # Save as .png
        png_path = os.path.join(png_folder, file_name.rsplit(".", 1)[0] + ".png")
        image.save(png_path, format="PNG", optimize=True)  # Save without losing data
        print(f"Converted: {jpeg_path} -> {png_path}")

print("All files converted successfully.")
# Out:
# Converted: /content/dataset/V2/Images/scene00113.jpeg -> /content/dataset/V2/Imagespng/scene00113.png
# Converted: /content/dataset/V2/Images/scene00066.jpeg -> /content/dataset/V2/Imagespng/scene00066.png
# Converted: /content/dataset/V2/Images/scene00056.jpeg -> /content/dataset/V2/Imagespng/scene00056.png
# Converted: /content/dataset/V2/Images/scene00094.jpeg -> /content/dataset/V2/Imagespng/scene00094.png
# Converted: /content/dataset/V2/Images/scene00072.jpeg -> /content/dataset/V2/Imagespng/scene00072.png
# Converted: /content/dataset/V2/Images/scene00149.jpeg -> /content/dataset/V2/Imagespng/scene00149.png
# Converted: /content/dataset/V2/Images/scene00107.jpeg -> /content/dataset/V2/Imagespng/scene00107.png
# Converted: /content/dataset/V2/Images/scene00076.jpeg -> /content/dataset/V2/Imagespng/scene00076.png
# Converted: /content/dataset/V2/Images/scene00140.jpeg -> /content/dataset/V2/Imagespng/scene00140.png
# Converted: /content/dataset/V2/Images/scene00121.jpeg -> /content/dataset/V2/Imagespng/scene00121.png
# Converted: /content/dataset/V2/Images/scene00142.jpeg -> /content/dataset/V2/Imagespng/scene00142.png
# Converted: /content/dataset/V2/Images/scene00051.jpeg -> /content/dataset/V2/Imagespng/scene00051.png
# Converted: /content/dataset/V2/Images/scene00045.jpeg -> /content/dataset/V2/Imagespng/scene00045.png
# Converted: /content/dataset/V2/Images/scene00127.jpeg -> /content/dataset/V2/Imagespng/scene00127.png
# Converted: /content/dataset/V2/Images/scene00131.jpeg -> /content/dataset/V2/Imagespng/scene00131.png
# Converted: /content/dataset/V2/Images/scene00054.jpeg -> /content/dataset/V2/Imagespng/scene00054.png
# Converted: /content/dataset/V2/Images/scene00068.jpeg -> /content/dataset/V2/Imagespng/scene00068.png
# Converted: /content/dataset/V2/Images/scene00069.jpeg -> /content/dataset/V2/Imagespng/scene00069.png
# Converted: /content/dataset/V2/Images/scene00124.jpeg -> /content/dataset/V2/Imagespng/scene00124.png
# Converted: /content/dataset/V2/Images/scene00060.jpeg -> /content/dataset/V2/Imagespng/scene00060.png
# Converted: /content/dataset/V2/Images/scene00086.jpeg -> /content/dataset/V2/Imagespng/scene00086.png
# Converted: /content/dataset/V2/Images/scene00105.jpeg -> /content/dataset/V2/Imagespng/scene00105.png
# Converted: /content/dataset/V2/Images/scene00023.jpeg -> /content/dataset/V2/Imagespng/scene00023.png
# Converted: /content/dataset/V2/Images/scene00061.jpeg -> /content/dataset/V2/Imagespng/scene00061.png
# Converted: /content/dataset/V2/Images/scene00034.jpeg -> /content/dataset/V2/Imagespng/scene00034.png
# Converted: /content/dataset/V2/Images/scene00024.jpeg -> /content/dataset/V2/Imagespng/scene00024.png
# Converted: /content/dataset/V2/Images/scene00062.jpeg -> /content/dataset/V2/Imagespng/scene00062.png
# Converted: /content/dataset/V2/Images/scene00022.jpeg -> /content/dataset/V2/Imagespng/scene00022.png
# Converted: /content/dataset/V2/Images/scene00040.jpeg -> /content/dataset/V2/Imagespng/scene00040.png
# Converted: /content/dataset/V2/Images/scene00136.jpeg -> /content/dataset/V2/Imagespng/scene00136.png
# Converted: /content/dataset/V2/Images/scene00025.jpeg -> /content/dataset/V2/Imagespng/scene00025.png
# Converted: /content/dataset/V2/Images/scene00032.jpeg -> /content/dataset/V2/Imagespng/scene00032.png
# Converted: /content/dataset/V2/Images/scene00036.jpeg -> /content/dataset/V2/Imagespng/scene00036.png
# Converted: /content/dataset/V2/Images/scene00029.jpeg -> /content/dataset/V2/Imagespng/scene00029.png
# Converted: /content/dataset/V2/Images/scene00027.jpeg -> /content/dataset/V2/Imagespng/scene00027.png
# Converted: /content/dataset/V2/Images/scene00117.jpeg -> /content/dataset/V2/Imagespng/scene00117.png
# Converted: /content/dataset/V2/Images/scene00053.jpeg -> /content/dataset/V2/Imagespng/scene00053.png
# Converted: /content/dataset/V2/Images/scene00150.jpeg -> /content/dataset/V2/Imagespng/scene00150.png
# Converted: /content/dataset/V2/Images/scene00092.jpeg -> /content/dataset/V2/Imagespng/scene00092.png
# Converted: /content/dataset/V2/Images/scene00057.jpeg -> /content/dataset/V2/Imagespng/scene00057.png
# Converted: /content/dataset/V2/Images/scene00141.jpeg -> /content/dataset/V2/Imagespng/scene00141.png
# Converted: /content/dataset/V2/Images/scene00139.jpeg -> /content/dataset/V2/Imagespng/scene00139.png
# Converted: /content/dataset/V2/Images/scene00126.jpeg -> /content/dataset/V2/Imagespng/scene00126.png
# Converted: /content/dataset/V2/Images/scene00097.jpeg -> /content/dataset/V2/Imagespng/scene00097.png
# Converted: /content/dataset/V2/Images/scene00083.jpeg -> /content/dataset/V2/Imagespng/scene00083.png
# Converted: /content/dataset/V2/Images/scene00133.jpeg -> /content/dataset/V2/Imagespng/scene00133.png
# Converted: /content/dataset/V2/Images/scene00043.jpeg -> /content/dataset/V2/Imagespng/scene00043.png
# Converted: /content/dataset/V2/Images/scene00103.jpeg -> /content/dataset/V2/Imagespng/scene00103.png
# Converted: /content/dataset/V2/Images/scene00112.jpeg -> /content/dataset/V2/Imagespng/scene00112.png
# Converted: /content/dataset/V2/Images/scene00041.jpeg -> /content/dataset/V2/Imagespng/scene00041.png
# Converted: /content/dataset/V2/Images/scene00128.jpeg -> /content/dataset/V2/Imagespng/scene00128.png
# Converted: /content/dataset/V2/Images/scene00093.jpeg -> /content/dataset/V2/Imagespng/scene00093.png
# Converted: /content/dataset/V2/Images/scene00084.jpeg -> /content/dataset/V2/Imagespng/scene00084.png
# Converted: /content/dataset/V2/Images/scene00100.jpeg -> /content/dataset/V2/Imagespng/scene00100.png
# Converted: /content/dataset/V2/Images/scene00079.jpeg -> /content/dataset/V2/Imagespng/scene00079.png
# Converted: /content/dataset/V2/Images/scene00138.jpeg -> /content/dataset/V2/Imagespng/scene00138.png
# Converted: /content/dataset/V2/Images/scene00085.jpeg -> /content/dataset/V2/Imagespng/scene00085.png
# Converted: /content/dataset/V2/Images/scene00037.jpeg -> /content/dataset/V2/Imagespng/scene00037.png
# Converted: /content/dataset/V2/Images/scene00044.jpeg -> /content/dataset/V2/Imagespng/scene00044.png
# Converted: /content/dataset/V2/Images/scene00122.jpeg -> /content/dataset/V2/Imagespng/scene00122.png
# Converted: /content/dataset/V2/Images/scene00039.jpeg -> /content/dataset/V2/Imagespng/scene00039.png
# Converted: /content/dataset/V2/Images/scene00048.jpeg -> /content/dataset/V2/Imagespng/scene00048.png
# Converted: /content/dataset/V2/Images/scene00073.jpeg -> /content/dataset/V2/Imagespng/scene00073.png
# Converted: /content/dataset/V2/Images/scene00095.jpeg -> /content/dataset/V2/Imagespng/scene00095.png
# Converted: /content/dataset/V2/Images/scene00091.jpeg -> /content/dataset/V2/Imagespng/scene00091.png
# Converted: /content/dataset/V2/Images/scene00148.jpeg -> /content/dataset/V2/Imagespng/scene00148.png
# Converted: /content/dataset/V2/Images/scene00145.jpeg -> /content/dataset/V2/Imagespng/scene00145.png
# Converted: /content/dataset/V2/Images/scene00082.jpeg -> /content/dataset/V2/Imagespng/scene00082.png
# Converted: /content/dataset/V2/Images/scene00096.jpeg -> /content/dataset/V2/Imagespng/scene00096.png
# Converted: /content/dataset/V2/Images/scene00123.jpeg -> /content/dataset/V2/Imagespng/scene00123.png
# Converted: /content/dataset/V2/Images/scene00033.jpeg -> /content/dataset/V2/Imagespng/scene00033.png
# Converted: /content/dataset/V2/Images/scene00050.jpeg -> /content/dataset/V2/Imagespng/scene00050.png
# Converted: /content/dataset/V2/Images/scene00071.jpeg -> /content/dataset/V2/Imagespng/scene00071.png
# Converted: /content/dataset/V2/Images/scene00047.jpeg -> /content/dataset/V2/Imagespng/scene00047.png
# Converted: /content/dataset/V2/Images/scene00111.jpeg -> /content/dataset/V2/Imagespng/scene00111.png
# Converted: /content/dataset/V2/Images/scene00088.jpeg -> /content/dataset/V2/Imagespng/scene00088.png
# Converted: /content/dataset/V2/Images/scene00077.jpeg -> /content/dataset/V2/Imagespng/scene00077.png
# Converted: /content/dataset/V2/Images/scene00110.jpeg -> /content/dataset/V2/Imagespng/scene00110.png
# Converted: /content/dataset/V2/Images/scene00030.jpeg -> /content/dataset/V2/Imagespng/scene00030.png
# Converted: /content/dataset/V2/Images/scene00118.jpeg -> /content/dataset/V2/Imagespng/scene00118.png
# Converted: /content/dataset/V2/Images/scene00049.jpeg -> /content/dataset/V2/Imagespng/scene00049.png
# Converted: /content/dataset/V2/Images/scene00067.jpeg -> /content/dataset/V2/Imagespng/scene00067.png
# Converted: /content/dataset/V2/Images/scene00147.jpeg -> /content/dataset/V2/Imagespng/scene00147.png
# Converted: /content/dataset/V2/Images/scene00038.jpeg -> /content/dataset/V2/Imagespng/scene00038.png
# Converted: /content/dataset/V2/Images/scene00059.jpeg -> /content/dataset/V2/Imagespng/scene00059.png
# Converted: /content/dataset/V2/Images/scene00089.jpeg -> /content/dataset/V2/Imagespng/scene00089.png
# Converted: /content/dataset/V2/Images/scene00104.jpeg -> /content/dataset/V2/Imagespng/scene00104.png
# Converted: /content/dataset/V2/Images/scene00090.jpeg -> /content/dataset/V2/Imagespng/scene00090.png
# Converted: /content/dataset/V2/Images/scene00129.jpeg -> /content/dataset/V2/Imagespng/scene00129.png
# Converted: /content/dataset/V2/Images/scene00146.jpeg -> /content/dataset/V2/Imagespng/scene00146.png
# Converted: /content/dataset/V2/Images/scene00099.jpeg -> /content/dataset/V2/Imagespng/scene00099.png
# Converted: /content/dataset/V2/Images/scene00125.jpeg -> /content/dataset/V2/Imagespng/scene00125.png
# Converted: /content/dataset/V2/Images/scene00134.jpeg -> /content/dataset/V2/Imagespng/scene00134.png
# Converted: /content/dataset/V2/Images/scene00119.jpeg -> /content/dataset/V2/Imagespng/scene00119.png
# Converted: /content/dataset/V2/Images/scene00058.jpeg -> /content/dataset/V2/Imagespng/scene00058.png
# Converted: /content/dataset/V2/Images/scene00035.jpeg -> /content/dataset/V2/Imagespng/scene00035.png
# Converted: /content/dataset/V2/Images/scene00098.jpeg -> /content/dataset/V2/Imagespng/scene00098.png
# Converted: /content/dataset/V2/Images/scene00074.jpeg -> /content/dataset/V2/Imagespng/scene00074.png
# Converted: /content/dataset/V2/Images/scene00143.jpeg -> /content/dataset/V2/Imagespng/scene00143.png
# Converted: /content/dataset/V2/Images/scene00087.jpeg -> /content/dataset/V2/Imagespng/scene00087.png
# Converted: /content/dataset/V2/Images/scene00108.jpeg -> /content/dataset/V2/Imagespng/scene00108.png
# Converted: /content/dataset/V2/Images/scene00026.jpeg -> /content/dataset/V2/Imagespng/scene00026.png
# Converted: /content/dataset/V2/Images/scene00102.jpeg -> /content/dataset/V2/Imagespng/scene00102.png
# Converted: /content/dataset/V2/Images/scene00135.jpeg -> /content/dataset/V2/Imagespng/scene00135.png
# Converted: /content/dataset/V2/Images/scene00063.jpeg -> /content/dataset/V2/Imagespng/scene00063.png
# Converted: /content/dataset/V2/Images/scene00075.jpeg -> /content/dataset/V2/Imagespng/scene00075.png
# Converted: /content/dataset/V2/Images/scene00106.jpeg -> /content/dataset/V2/Imagespng/scene00106.png
# Converted: /content/dataset/V2/Images/scene00055.jpeg -> /content/dataset/V2/Imagespng/scene00055.png
# Converted: /content/dataset/V2/Images/scene00109.jpeg -> /content/dataset/V2/Imagespng/scene00109.png
# Converted: /content/dataset/V2/Images/scene00064.jpeg -> /content/dataset/V2/Imagespng/scene00064.png
# Converted: /content/dataset/V2/Images/scene00144.jpeg -> /content/dataset/V2/Imagespng/scene00144.png
# Converted: /content/dataset/V2/Images/scene00080.jpeg -> /content/dataset/V2/Imagespng/scene00080.png
# Converted: /content/dataset/V2/Images/scene00120.jpeg -> /content/dataset/V2/Imagespng/scene00120.png
# Converted: /content/dataset/V2/Images/scene00052.jpeg -> /content/dataset/V2/Imagespng/scene00052.png
# Converted: /content/dataset/V2/Images/scene00101.jpeg -> /content/dataset/V2/Imagespng/scene00101.png
# Converted: /content/dataset/V2/Images/scene00081.jpeg -> /content/dataset/V2/Imagespng/scene00081.png
# Converted: /content/dataset/V2/Images/scene00130.jpeg -> /content/dataset/V2/Imagespng/scene00130.png
# Converted: /content/dataset/V2/Images/scene00137.jpeg -> /content/dataset/V2/Imagespng/scene00137.png
# Converted: /content/dataset/V2/Images/scene00042.jpeg -> /content/dataset/V2/Imagespng/scene00042.png
# Converted: /content/dataset/V2/Images/scene00065.jpeg -> /content/dataset/V2/Imagespng/scene00065.png
# Converted: /content/dataset/V2/Images/scene00116.jpeg -> /content/dataset/V2/Imagespng/scene00116.png
# Converted: /content/dataset/V2/Images/scene00028.jpeg -> /content/dataset/V2/Imagespng/scene00028.png
# Converted: /content/dataset/V2/Images/scene00078.jpeg -> /content/dataset/V2/Imagespng/scene00078.png
# Converted: /content/dataset/V2/Images/scene00115.jpeg -> /content/dataset/V2/Imagespng/scene00115.png
# Converted: /content/dataset/V2/Images/scene00132.jpeg -> /content/dataset/V2/Imagespng/scene00132.png
# Converted: /content/dataset/V2/Images/scene00031.jpeg -> /content/dataset/V2/Imagespng/scene00031.png
# Converted: /content/dataset/V2/Images/scene00070.jpeg -> /content/dataset/V2/Imagespng/scene00070.png
# Converted: /content/dataset/V2/Images/scene00046.jpeg -> /content/dataset/V2/Imagespng/scene00046.png
# All files converted successfully.

# %%
import os
from PIL import Image

# Define paths
jpeg_folder = "/content/dataset/V3/Images/"  # Replace with your folder containing .jpeg files
png_folder = "/content/dataset/V3/Imagespng"   # Replace with your desired output folder for .png files

# Create output folder if it doesn't exist
os.makedirs(png_folder, exist_ok=True)

# Loop through all files in the .jpeg folder
for file_name in os.listdir(jpeg_folder):
    if file_name.endswith(".jpeg") or file_name.endswith(".jpg"):
        # Open the .jpeg file
        jpeg_path = os.path.join(jpeg_folder, file_name)
        image = Image.open(jpeg_path)

        # Save as .png
        png_path = os.path.join(png_folder, file_name.rsplit(".", 1)[0] + ".png")
        image.save(png_path, format="PNG", optimize=True)  # Save without losing data
        print(f"Converted: {jpeg_path} -> {png_path}")

print("All files converted successfully.")
# Out:
# Converted: /content/dataset/V3/Images/scene00113.jpeg -> /content/dataset/V3/Imagespng/scene00113.png
# Converted: /content/dataset/V3/Images/scene00066.jpeg -> /content/dataset/V3/Imagespng/scene00066.png
# Converted: /content/dataset/V3/Images/scene00056.jpeg -> /content/dataset/V3/Imagespng/scene00056.png
# Converted: /content/dataset/V3/Images/scene00094.jpeg -> /content/dataset/V3/Imagespng/scene00094.png
# Converted: /content/dataset/V3/Images/scene00072.jpeg -> /content/dataset/V3/Imagespng/scene00072.png
# Converted: /content/dataset/V3/Images/scene00007.jpeg -> /content/dataset/V3/Imagespng/scene00007.png
# Converted: /content/dataset/V3/Images/scene00107.jpeg -> /content/dataset/V3/Imagespng/scene00107.png
# Converted: /content/dataset/V3/Images/scene00076.jpeg -> /content/dataset/V3/Imagespng/scene00076.png
# Converted: /content/dataset/V3/Images/scene00121.jpeg -> /content/dataset/V3/Imagespng/scene00121.png
# Converted: /content/dataset/V3/Images/scene00017.jpeg -> /content/dataset/V3/Imagespng/scene00017.png
# Converted: /content/dataset/V3/Images/scene00051.jpeg -> /content/dataset/V3/Imagespng/scene00051.png
# Converted: /content/dataset/V3/Images/scene00045.jpeg -> /content/dataset/V3/Imagespng/scene00045.png
# Converted: /content/dataset/V3/Images/scene00127.jpeg -> /content/dataset/V3/Imagespng/scene00127.png
# Converted: /content/dataset/V3/Images/scene00054.jpeg -> /content/dataset/V3/Imagespng/scene00054.png
# Converted: /content/dataset/V3/Images/scene00068.jpeg -> /content/dataset/V3/Imagespng/scene00068.png
# Converted: /content/dataset/V3/Images/scene00069.jpeg -> /content/dataset/V3/Imagespng/scene00069.png
# Converted: /content/dataset/V3/Images/scene00004.jpeg -> /content/dataset/V3/Imagespng/scene00004.png
# Converted: /content/dataset/V3/Images/scene00124.jpeg -> /content/dataset/V3/Imagespng/scene00124.png
# Converted: /content/dataset/V3/Images/scene00060.jpeg -> /content/dataset/V3/Imagespng/scene00060.png
# Converted: /content/dataset/V3/Images/scene00086.jpeg -> /content/dataset/V3/Imagespng/scene00086.png
# Converted: /content/dataset/V3/Images/scene00023.jpeg -> /content/dataset/V3/Imagespng/scene00023.png
# Converted: /content/dataset/V3/Images/scene00061.jpeg -> /content/dataset/V3/Imagespng/scene00061.png
# Converted: /content/dataset/V3/Images/scene00034.jpeg -> /content/dataset/V3/Imagespng/scene00034.png
# Converted: /content/dataset/V3/Images/scene00024.jpeg -> /content/dataset/V3/Imagespng/scene00024.png
# Converted: /content/dataset/V3/Images/scene00062.jpeg -> /content/dataset/V3/Imagespng/scene00062.png
# Converted: /content/dataset/V3/Images/scene00022.jpeg -> /content/dataset/V3/Imagespng/scene00022.png
# Converted: /content/dataset/V3/Images/scene00040.jpeg -> /content/dataset/V3/Imagespng/scene00040.png
# Converted: /content/dataset/V3/Images/scene00025.jpeg -> /content/dataset/V3/Imagespng/scene00025.png
# Converted: /content/dataset/V3/Images/scene00032.jpeg -> /content/dataset/V3/Imagespng/scene00032.png
# Converted: /content/dataset/V3/Images/scene00036.jpeg -> /content/dataset/V3/Imagespng/scene00036.png
# Converted: /content/dataset/V3/Images/scene00003.jpeg -> /content/dataset/V3/Imagespng/scene00003.png
# Converted: /content/dataset/V3/Images/scene00029.jpeg -> /content/dataset/V3/Imagespng/scene00029.png
# Converted: /content/dataset/V3/Images/scene00027.jpeg -> /content/dataset/V3/Imagespng/scene00027.png
# Converted: /content/dataset/V3/Images/scene00117.jpeg -> /content/dataset/V3/Imagespng/scene00117.png
# Converted: /content/dataset/V3/Images/scene00053.jpeg -> /content/dataset/V3/Imagespng/scene00053.png
# Converted: /content/dataset/V3/Images/scene00018.jpeg -> /content/dataset/V3/Imagespng/scene00018.png
# Converted: /content/dataset/V3/Images/scene00092.jpeg -> /content/dataset/V3/Imagespng/scene00092.png
# Converted: /content/dataset/V3/Images/scene00057.jpeg -> /content/dataset/V3/Imagespng/scene00057.png
# Converted: /content/dataset/V3/Images/scene00126.jpeg -> /content/dataset/V3/Imagespng/scene00126.png
# Converted: /content/dataset/V3/Images/scene00097.jpeg -> /content/dataset/V3/Imagespng/scene00097.png
# Converted: /content/dataset/V3/Images/scene00083.jpeg -> /content/dataset/V3/Imagespng/scene00083.png
# Converted: /content/dataset/V3/Images/scene00005.jpeg -> /content/dataset/V3/Imagespng/scene00005.png
# Converted: /content/dataset/V3/Images/scene00043.jpeg -> /content/dataset/V3/Imagespng/scene00043.png
# Converted: /content/dataset/V3/Images/scene00014.jpeg -> /content/dataset/V3/Imagespng/scene00014.png
# Converted: /content/dataset/V3/Images/scene00103.jpeg -> /content/dataset/V3/Imagespng/scene00103.png
# Converted: /content/dataset/V3/Images/scene00112.jpeg -> /content/dataset/V3/Imagespng/scene00112.png
# Converted: /content/dataset/V3/Images/scene00114.jpeg -> /content/dataset/V3/Imagespng/scene00114.png
# Converted: /content/dataset/V3/Images/scene00020.jpeg -> /content/dataset/V3/Imagespng/scene00020.png
# Converted: /content/dataset/V3/Images/scene00041.jpeg -> /content/dataset/V3/Imagespng/scene00041.png
# Converted: /content/dataset/V3/Images/scene00128.jpeg -> /content/dataset/V3/Imagespng/scene00128.png
# Converted: /content/dataset/V3/Images/scene00093.jpeg -> /content/dataset/V3/Imagespng/scene00093.png
# Converted: /content/dataset/V3/Images/scene00084.jpeg -> /content/dataset/V3/Imagespng/scene00084.png
# Converted: /content/dataset/V3/Images/scene00100.jpeg -> /content/dataset/V3/Imagespng/scene00100.png
# Converted: /content/dataset/V3/Images/scene00079.jpeg -> /content/dataset/V3/Imagespng/scene00079.png
# Converted: /content/dataset/V3/Images/scene00085.jpeg -> /content/dataset/V3/Imagespng/scene00085.png
# Converted: /content/dataset/V3/Images/scene00037.jpeg -> /content/dataset/V3/Imagespng/scene00037.png
# Converted: /content/dataset/V3/Images/scene00044.jpeg -> /content/dataset/V3/Imagespng/scene00044.png
# Converted: /content/dataset/V3/Images/scene00006.jpeg -> /content/dataset/V3/Imagespng/scene00006.png
# Converted: /content/dataset/V3/Images/scene00016.jpeg -> /content/dataset/V3/Imagespng/scene00016.png
# Converted: /content/dataset/V3/Images/scene00122.jpeg -> /content/dataset/V3/Imagespng/scene00122.png
# Converted: /content/dataset/V3/Images/scene00039.jpeg -> /content/dataset/V3/Imagespng/scene00039.png
# Converted: /content/dataset/V3/Images/scene00048.jpeg -> /content/dataset/V3/Imagespng/scene00048.png
# Converted: /content/dataset/V3/Images/scene00073.jpeg -> /content/dataset/V3/Imagespng/scene00073.png
# Converted: /content/dataset/V3/Images/scene00095.jpeg -> /content/dataset/V3/Imagespng/scene00095.png
# Converted: /content/dataset/V3/Images/scene00091.jpeg -> /content/dataset/V3/Imagespng/scene00091.png
# Converted: /content/dataset/V3/Images/scene00082.jpeg -> /content/dataset/V3/Imagespng/scene00082.png
# Converted: /content/dataset/V3/Images/scene00096.jpeg -> /content/dataset/V3/Imagespng/scene00096.png
# Converted: /content/dataset/V3/Images/scene00123.jpeg -> /content/dataset/V3/Imagespng/scene00123.png
# Converted: /content/dataset/V3/Images/scene00033.jpeg -> /content/dataset/V3/Imagespng/scene00033.png
# Converted: /content/dataset/V3/Images/scene00050.jpeg -> /content/dataset/V3/Imagespng/scene00050.png
# Converted: /content/dataset/V3/Images/scene00071.jpeg -> /content/dataset/V3/Imagespng/scene00071.png
# Converted: /content/dataset/V3/Images/scene00047.jpeg -> /content/dataset/V3/Imagespng/scene00047.png
# Converted: /content/dataset/V3/Images/scene00111.jpeg -> /content/dataset/V3/Imagespng/scene00111.png
# Converted: /content/dataset/V3/Images/scene00088.jpeg -> /content/dataset/V3/Imagespng/scene00088.png
# Converted: /content/dataset/V3/Images/scene00077.jpeg -> /content/dataset/V3/Imagespng/scene00077.png
# Converted: /content/dataset/V3/Images/scene00110.jpeg -> /content/dataset/V3/Imagespng/scene00110.png
# Converted: /content/dataset/V3/Images/scene00030.jpeg -> /content/dataset/V3/Imagespng/scene00030.png
# Converted: /content/dataset/V3/Images/scene00118.jpeg -> /content/dataset/V3/Imagespng/scene00118.png
# Converted: /content/dataset/V3/Images/scene00002.jpeg -> /content/dataset/V3/Imagespng/scene00002.png
# Converted: /content/dataset/V3/Images/scene00049.jpeg -> /content/dataset/V3/Imagespng/scene00049.png
# Converted: /content/dataset/V3/Images/scene00067.jpeg -> /content/dataset/V3/Imagespng/scene00067.png
# Converted: /content/dataset/V3/Images/scene00038.jpeg -> /content/dataset/V3/Imagespng/scene00038.png
# Converted: /content/dataset/V3/Images/scene00059.jpeg -> /content/dataset/V3/Imagespng/scene00059.png
# Converted: /content/dataset/V3/Images/scene00089.jpeg -> /content/dataset/V3/Imagespng/scene00089.png
# Converted: /content/dataset/V3/Images/scene00104.jpeg -> /content/dataset/V3/Imagespng/scene00104.png
# Converted: /content/dataset/V3/Images/scene00090.jpeg -> /content/dataset/V3/Imagespng/scene00090.png
# Converted: /content/dataset/V3/Images/scene00129.jpeg -> /content/dataset/V3/Imagespng/scene00129.png
# Converted: /content/dataset/V3/Images/scene00015.jpeg -> /content/dataset/V3/Imagespng/scene00015.png
# Converted: /content/dataset/V3/Images/scene00099.jpeg -> /content/dataset/V3/Imagespng/scene00099.png
# Converted: /content/dataset/V3/Images/scene00125.jpeg -> /content/dataset/V3/Imagespng/scene00125.png
# Converted: /content/dataset/V3/Images/scene00008.jpeg -> /content/dataset/V3/Imagespng/scene00008.png
# Converted: /content/dataset/V3/Images/scene00119.jpeg -> /content/dataset/V3/Imagespng/scene00119.png
# Converted: /content/dataset/V3/Images/scene00035.jpeg -> /content/dataset/V3/Imagespng/scene00035.png
# Converted: /content/dataset/V3/Images/scene00098.jpeg -> /content/dataset/V3/Imagespng/scene00098.png
# Converted: /content/dataset/V3/Images/scene00074.jpeg -> /content/dataset/V3/Imagespng/scene00074.png
# Converted: /content/dataset/V3/Images/scene00087.jpeg -> /content/dataset/V3/Imagespng/scene00087.png
# Converted: /content/dataset/V3/Images/scene00108.jpeg -> /content/dataset/V3/Imagespng/scene00108.png
# Converted: /content/dataset/V3/Images/scene00026.jpeg -> /content/dataset/V3/Imagespng/scene00026.png
# Converted: /content/dataset/V3/Images/scene00102.jpeg -> /content/dataset/V3/Imagespng/scene00102.png
# Converted: /content/dataset/V3/Images/scene00063.jpeg -> /content/dataset/V3/Imagespng/scene00063.png
# Converted: /content/dataset/V3/Images/scene00075.jpeg -> /content/dataset/V3/Imagespng/scene00075.png
# Converted: /content/dataset/V3/Images/scene00001.jpeg -> /content/dataset/V3/Imagespng/scene00001.png
# Converted: /content/dataset/V3/Images/scene00106.jpeg -> /content/dataset/V3/Imagespng/scene00106.png
# Converted: /content/dataset/V3/Images/scene00012.jpeg -> /content/dataset/V3/Imagespng/scene00012.png
# Converted: /content/dataset/V3/Images/scene00055.jpeg -> /content/dataset/V3/Imagespng/scene00055.png
# Converted: /content/dataset/V3/Images/scene00109.jpeg -> /content/dataset/V3/Imagespng/scene00109.png
# Converted: /content/dataset/V3/Images/scene00064.jpeg -> /content/dataset/V3/Imagespng/scene00064.png
# Converted: /content/dataset/V3/Images/scene00013.jpeg -> /content/dataset/V3/Imagespng/scene00013.png
# Converted: /content/dataset/V3/Images/scene00011.jpeg -> /content/dataset/V3/Imagespng/scene00011.png
# Converted: /content/dataset/V3/Images/scene00021.jpeg -> /content/dataset/V3/Imagespng/scene00021.png
# Converted: /content/dataset/V3/Images/scene00080.jpeg -> /content/dataset/V3/Imagespng/scene00080.png
# Converted: /content/dataset/V3/Images/scene00010.jpeg -> /content/dataset/V3/Imagespng/scene00010.png
# Converted: /content/dataset/V3/Images/scene00019.jpeg -> /content/dataset/V3/Imagespng/scene00019.png
# Converted: /content/dataset/V3/Images/scene00052.jpeg -> /content/dataset/V3/Imagespng/scene00052.png
# Converted: /content/dataset/V3/Images/scene00101.jpeg -> /content/dataset/V3/Imagespng/scene00101.png
# Converted: /content/dataset/V3/Images/scene00009.jpeg -> /content/dataset/V3/Imagespng/scene00009.png
# Converted: /content/dataset/V3/Images/scene00081.jpeg -> /content/dataset/V3/Imagespng/scene00081.png
# Converted: /content/dataset/V3/Images/scene00130.jpeg -> /content/dataset/V3/Imagespng/scene00130.png
# Converted: /content/dataset/V3/Images/scene00042.jpeg -> /content/dataset/V3/Imagespng/scene00042.png
# Converted: /content/dataset/V3/Images/scene00065.jpeg -> /content/dataset/V3/Imagespng/scene00065.png
# Converted: /content/dataset/V3/Images/scene00116.jpeg -> /content/dataset/V3/Imagespng/scene00116.png
# Converted: /content/dataset/V3/Images/scene00028.jpeg -> /content/dataset/V3/Imagespng/scene00028.png
# Converted: /content/dataset/V3/Images/scene00078.jpeg -> /content/dataset/V3/Imagespng/scene00078.png
# Converted: /content/dataset/V3/Images/scene00115.jpeg -> /content/dataset/V3/Imagespng/scene00115.png
# Converted: /content/dataset/V3/Images/scene00031.jpeg -> /content/dataset/V3/Imagespng/scene00031.png
# Converted: /content/dataset/V3/Images/scene00070.jpeg -> /content/dataset/V3/Imagespng/scene00070.png
# Converted: /content/dataset/V3/Images/scene00046.jpeg -> /content/dataset/V3/Imagespng/scene00046.png
# All files converted successfully.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Function to load and preprocess image
def load_image(image_path):
    # Load the image in grayscale mode
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    img = cv2.resize(img, (128,128))#change size of input image here...

    img = img / 255.0

    return img

# %% [markdown]
# INterRouted Method:

# %%
import tensorflow as tf

class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_folder, mask_folder, file_list, batch_size, image_size=(128,128)):
        self.image_folder = image_folder
        self.mask_folder = mask_folder
        self.file_list = file_list
        self.batch_size = batch_size
        self.image_size = image_size

    def __len__(self):
        return int(np.ceil(len(self.file_list) / self.batch_size))

    def __getitem__(self, index):
        batch_files = self.file_list[index * self.batch_size:(index + 1) * self.batch_size]

        images = np.zeros((len(batch_files), self.image_size[0], self.image_size[1], 1))
        masks = np.zeros((len(batch_files), self.image_size[0], self.image_size[1], 1))

        for i, filename in enumerate(batch_files):
            img_path = os.path.join(self.image_folder, filename)
            mask_path = os.path.join(self.mask_folder, filename)

            # Load and preprocess image
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                raise ValueError(f"Error loading image from {img_path}")
            img = cv2.resize(img, self.image_size) / 255.0
            img = np.expand_dims(img, axis=-1)

            # Load and preprocess mask
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            if mask is None:
                raise ValueError(f"Error loading mask from {mask_path}")
            mask = cv2.resize(mask, self.image_size) / 255.0
            mask = np.expand_dims(mask, axis=-1)

            images[i] = img
            masks[i] = mask

        return images, masks

# %% [markdown]
# **Light Weight UNet Model**

# %%
# !pip install keras_unet_collection
# Out:
# Collecting keras_unet_collection
#   Downloading keras_unet_collection-0.1.13-py3-none-any.whl.metadata (8.0 kB)
# Downloading keras_unet_collection-0.1.13-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: keras_unet_collection
# Successfully installed keras_unet_collection-0.1.13

# %%
from keras_unet_collection import models

# %%
from keras_unet_collection import models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import tensorflow as tf
import os

# Define paths
IMAGE_PATH = "/content/dataset/V2/Imagespng"
MASK_PATH = "/content/dataset/V2/Annotations"

# Modified model definition for single-channel input
def build_lightweight_unet():
    model = models.unet_2d(
        input_size=(128, 128, 1),
        filter_num=[2,4,8,16,32],
        n_labels=1,
        stack_num_down=2,
        stack_num_up=1,
        activation='ReLU',
        output_activation='Sigmoid',
        batch_norm=True,
        pool='max',
        unpool='nearest',
        name='lightweight_unet'
    )
    return model

model = build_lightweight_unet()

# %% [markdown]
# BiFocal Loss

# %%
import tensorflow as tf

def binary_focal_loss(gamma=2.0, alpha=0.25):
    """
    Binary focal loss with additional parameters for fine-tuning
    gamma: focusing parameter for hard examples
    alpha: class weight parameter
    """
    def focal_loss(y_true, y_pred):
        # Cast inputs to float32 for consistency with wavelet processing
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)

        # Calculate focal loss
        loss = -y_true * alpha * tf.pow(1 - y_pred, gamma) * tf.math.log(y_pred) - \
               (1 - y_true) * (1 - alpha) * tf.pow(y_pred, gamma) * tf.math.log(1 - y_pred)
        return tf.reduce_mean(loss)
    return focal_loss

# Model compilation with focal loss
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    lo


# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

IMAGE_PATH="/content/dataset/V3/Imagespng"
MASK_PATH="/content/dataset/V3/AnnotationsWB"

# Split data
image_files = os.listdir(IMAGE_PATH)
train_files, val_files = train_test_split(image_files, test_size=0.1, random_state=42)

# Training setup remains the same, just use the new DataGenerator
train_data_gen = DataGenerator(
    image_folder=IMAGE_PATH,
    mask_folder=MASK_PATH,
    file_list=train_files,
    batch_size=batch_size
)

val_data_gen = DataGenerator(
    image_folder=IMAGE_PATH,
    mask_folder=MASK_PATH,
    file_list=val_files,
    batch_size=batch_size
)

# %%
# Extract a single batch from the train_data_gen
sample_images, sample_masks = train_data_gen[0]  # First batch

# Get the shape of a single image and mask from the batch
image_shape = sample_images[0].shape  # Shape of one image in the batch
mask_shape = sample_masks[0].shape   # Shape of one mask in the batch

print(f"Image shape: {image_shape}")
print(f"Mask shape: {mask_shape}")
# Out:
# Image shape: (128, 128, 1)
# Mask shape: (128, 128, 1)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss', save_best_only=True)

history = model.fit(
    train_data_gen,
    validation_data=val_data_gen,
    epochs=50,
    callbacks=[early_stopping, model_checkpoint, reduce_lr],
    verbose=1
)

model.save("LightWeightUNetLiver.h5")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 650ms/step - accuracy: 0.5883 - binary_io_u: 0.3617 - loss: 0.1487 - precision: 0.2762 - recall: 0.6434 - val_accuracy: 0.8093 - val_binary_io_u: 0.4065 - val_loss: 0.1094 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.9081 - binary_io_u: 0.7536 - loss: 0.1042 - precision: 0.7974 - recall: 0.7152 - val_accuracy: 0.8114 - val_binary_io_u: 0.4075 - val_loss: 0.1052 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9594 - binary_io_u: 0.8813 - loss: 0.0947 - precision: 0.9570 - recall: 0.8291 - val_accuracy: 0.8122 - val_binary_io_u: 0.4079 - val_loss: 0.0997 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9728 - binary_io_u: 0.9217 - loss: 0.0867 - precision: 0.9752 - recall: 0.8858 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0944 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9773 - binary_io_u: 0.9362 - loss: 0.0795 - precision: 0.9797 - recall: 0.9072 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0894 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9788 - binary_io_u: 0.9406 - loss: 0.0729 - precision: 0.9840 - recall: 0.9100 - val_accuracy: 0.8121 - val_binary_io_u: 0.4079 - val_loss: 0.0853 - val_precision: 0.0370 - val_recall: 2.5007e-05 - learning_rate: 0.0010
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9795 - binary_io_u: 0.9430 - loss: 0.0650 - precision: 0.9761 - recall: 0.9231 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0798 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9803 - binary_io_u: 0.9452 - loss: 0.0576 - precision: 0.9835 - recall: 0.9184 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0743 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9829 - binary_io_u: 0.9529 - loss: 0.0511 - precision: 0.9808 - recall: 0.9356 - val_accuracy: 0.8123 - val_binary_io_u: 0.4081 - val_loss: 0.0629 - val_precision: 1.0000 - val_recall: 3.2509e-04 - learning_rate: 0.0010
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9826 - binary_io_u: 0.9530 - loss: 0.0448 - precision: 0.9842 - recall: 0.9316 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0539 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9825 - binary_io_u: 0.9521 - loss: 0.0397 - precision: 0.9841 - recall: 0.9301 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0520 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9837 - binary_io_u: 0.9557 - loss: 0.0351 - precision: 0.9833 - recall: 0.9375 - val_accuracy: 0.8123 - val_binary_io_u: 0.4079 - val_loss: 0.0541 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9837 - binary_io_u: 0.9569 - loss: 0.0311 - precision: 0.9884 - recall: 0.9323 - val_accuracy: 0.8123 - val_binary_io_u: 0.4080 - val_loss: 0.0533 - val_precision: 1.0000 - val_recall: 1.7505e-04 - learning_rate: 0.0010
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9843 - binary_io_u: 0.9584 - loss: 0.0279 - precision: 0.9872 - recall: 0.9363 - val_accuracy: 0.8328 - val_binary_io_u: 0.4728 - val_loss: 0.0488 - val_precision: 0.9847 - val_recall: 0.1112 - learning_rate: 0.0010
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9853 - binary_io_u: 0.9611 - loss: 0.0251 - precision: 0.9888 - recall: 0.9398 - val_accuracy: 0.8344 - val_binary_io_u: 0.4777 - val_loss: 0.0497 - val_precision: 0.9923 - val_recall: 0.1193 - learning_rate: 0.0010
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9856 - binary_io_u: 0.9619 - loss: 0.0228 - precision: 0.9863 - recall: 0.9439 - val_accuracy: 0.8856 - val_binary_io_u: 0.6405 - val_loss: 0.0376 - val_precision: 0.9877 - val_recall: 0.3964 - learning_rate: 0.0010
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9847 - binary_io_u: 0.9594 - loss: 0.0206 - precision: 0.9893 - recall: 0.9358 - val_accuracy: 0.8434 - val_binary_io_u: 0.5061 - val_loss: 0.0441 - val_precision: 0.9917 - val_recall: 0.1675 - learning_rate: 0.0010
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9855 - binary_io_u: 0.9626 - loss: 0.0185 - precision: 0.9921 - recall: 0.9372 - val_accuracy: 0.9159 - val_binary_io_u: 0.7372 - val_loss: 0.0261 - val_precision: 0.9876 - val_recall: 0.5607 - learning_rate: 0.0010
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9852 - binary_io_u: 0.9613 - loss: 0.0170 - precision: 0.9904 - recall: 0.9373 - val_accuracy: 0.9566 - val_binary_io_u: 0.8703 - val_loss: 0.0235 - val_precision: 0.9435 - val_recall: 0.8245 - learning_rate: 0.0010
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9853 - binary_io_u: 0.9613 - loss: 0.0156 - precision: 0.9887 - recall: 0.9404 - val_accuracy: 0.9625 - val_binary_io_u: 0.8872 - val_loss: 0.0145 - val_precision: 0.9744 - val_recall: 0.8267 - learning_rate: 0.0010
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9863 - binary_io_u: 0.9642 - loss: 0.0127 - precision: 0.9908 - recall: 0.9425 - val_accuracy: 0.9728 - val_binary_io_u: 0.9199 - val_loss: 0.0127 - val_precision: 0.9764 - val_recall: 0.8822 - learning_rate: 0.0010
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9877 - binary_io_u: 0.9687 - loss: 0.0113 - precision: 0.9930 - recall: 0.9481 - val_accuracy: 0.9686 - val_binary_io_u: 0.9065 - val_loss: 0.0129 - val_precision: 0.9803 - val_recall: 0.8555 - learning_rate: 0.0010
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9880 - binary_io_u: 0.9703 - loss: 0.0102 - precision: 0.9938 - recall: 0.9488 - val_accuracy: 0.9714 - val_binary_io_u: 0.9156 - val_loss: 0.0120 - val_precision: 0.9857 - val_recall: 0.8645 - learning_rate: 0.0010
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.9882 - binary_io_u: 0.9709 - loss: 0.0094 - precision: 0.9931 - recall: 0.9503 - val_accuracy: 0.9822 - val_binary_io_u: 0.9493 - val_loss: 0.0098 - val_precision: 0.9724 - val_recall: 0.9399 - learning_rate: 0.0010
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9886 - binary_io_u: 0.9714 - loss: 0.0086 - precision: 0.9931 - recall: 0.9526 - val_accuracy: 0.9809 - val_binary_io_u: 0.9447 - val_loss: 0.0097 - val_precision: 0.9680 - val_recall: 0.9379 - learning_rate: 0.0010
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9887 - binary_io_u: 0.9721 - loss: 0.0079 - precision: 0.9936 - recall: 0.9527 - val_accuracy: 0.9827 - val_binary_io_u: 0.9490 - val_loss: 0.0102 - val_precision: 0.9456 - val_recall: 0.9773 - learning_rate: 0.0010
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9890 - binary_io_u: 0.9732 - loss: 0.0073 - precision: 0.9939 - recall: 0.9540 - val_accuracy: 0.9835 - val_binary_io_u: 0.9532 - val_loss: 0.0091 - val_precision: 0.9652 - val_recall: 0.9553 - learning_rate: 0.0010
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9889 - binary_io_u: 0.9727 - loss: 0.0068 - precision: 0.9934 - recall: 0.9536 - val_accuracy: 0.9827 - val_binary_io_u: 0.9496 - val_loss: 0.0091 - val_precision: 0.9560 - val_recall: 0.9631 - learning_rate: 0.0010
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9895 - binary_io_u: 0.9747 - loss: 0.0063 - precision: 0.9937 - recall: 0.9579 - val_accuracy: 0.9836 - val_binary_io_u: 0.9526 - val_loss: 0.0091 - val_precision: 0.9542 - val_recall: 0.9710 - learning_rate: 0.0010
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9893 - binary_io_u: 0.9743 - loss: 0.0059 - precision: 0.9943 - recall: 0.9558 - val_accuracy: 0.9817 - val_binary_io_u: 0.9473 - val_loss: 0.0102 - val_precision: 0.9444 - val_recall: 0.9699 - learning_rate: 0.0010
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9888 - binary_io_u: 0.9726 - loss: 0.0057 - precision: 0.9918 - recall: 0.9562 - val_accuracy: 0.9834 - val_binary_io_u: 0.9528 - val_loss: 0.0084 - val_precision: 0.9579 - val_recall: 0.9631 - learning_rate: 0.0010
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9896 - binary_io_u: 0.9751 - loss: 0.0053 - precision: 0.9928 - recall: 0.9594 - val_accuracy: 0.9832 - val_binary_io_u: 0.9516 - val_loss: 0.0090 - val_precision: 0.9534 - val_recall: 0.9685 - learning_rate: 0.0010
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9893 - binary_io_u: 0.9738 - loss: 0.0051 - precision: 0.9921 - recall: 0.9574 - val_accuracy: 0.9807 - val_binary_io_u: 0.9432 - val_loss: 0.0101 - val_precision: 0.9350 - val_recall: 0.9788 - learning_rate: 0.0010
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9901 - binary_io_u: 0.9766 - loss: 0.0047 - precision: 0.9943 - recall: 0.9601 - val_accuracy: 0.9831 - val_binary_io_u: 0.9511 - val_loss: 0.0080 - val_precision: 0.9574 - val_recall: 0.9635 - learning_rate: 0.0010
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9903 - binary_io_u: 0.9773 - loss: 0.0044 - precision: 0.9945 - recall: 0.9610 - val_accuracy: 0.9828 - val_binary_io_u: 0.9507 - val_loss: 0.0085 - val_precision: 0.9504 - val_recall: 0.9696 - learning_rate: 0.0010
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9905 - binary_io_u: 0.9779 - loss: 0.0042 - precision: 0.9952 - recall: 0.9606 - val_accuracy: 0.9832 - val_binary_io_u: 0.9521 - val_loss: 0.0073 - val_precision: 0.9618 - val_recall: 0.9581 - learning_rate: 0.0010
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9909 - binary_io_u: 0.9789 - loss: 0.0040 - precision: 0.9954 - recall: 0.9623 - val_accuracy: 0.9832 - val_binary_io_u: 0.9518 - val_loss: 0.0074 - val_precision: 0.9583 - val_recall: 0.9627 - learning_rate: 0.0010
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9914 - binary_io_u: 0.9807 - loss: 0.0037 - precision: 0.9955 - recall: 0.9655 - val_accuracy: 0.9829 - val_binary_io_u: 0.9506 - val_loss: 0.0084 - val_precision: 0.9504 - val_recall: 0.9710 - learning_rate: 0.0010
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9916 - binary_io_u: 0.9814 - loss: 0.0035 - precision: 0.9954 - recall: 0.9668 - val_accuracy: 0.9823 - val_binary_io_u: 0.9492 - val_loss: 0.0083 - val_precision: 0.9503 - val_recall: 0.9667 - learning_rate: 0.0010
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9911 - binary_io_u: 0.9796 - loss: 0.0035 - precision: 0.9941 - recall: 0.9662 - val_accuracy: 0.9817 - val_binary_io_u: 0.9469 - val_loss: 0.0092 - val_precision: 0.9457 - val_recall: 0.9700 - learning_rate: 0.0010
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9907 - binary_io_u: 0.9779 - loss: 0.0035 - precision: 0.9930 - recall: 0.9646 - val_accuracy: 0.9828 - val_binary_io_u: 0.9509 - val_loss: 0.0085 - val_precision: 0.9520 - val_recall: 0.9669 - learning_rate: 0.0010
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9921 - binary_io_u: 0.9829 - loss: 0.0031 - precision: 0.9960 - recall: 0.9683 - val_accuracy: 0.9831 - val_binary_io_u: 0.9515 - val_loss: 0.0076 - val_precision: 0.9569 - val_recall: 0.9643 - learning_rate: 5.0000e-04
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9923 - binary_io_u: 0.9836 - loss: 0.0030 - precision: 0.9971 - recall: 0.9684 - val_accuracy: 0.9831 - val_binary_io_u: 0.9512 - val_loss: 0.0077 - val_precision: 0.9569 - val_recall: 0.9638 - learning_rate: 5.0000e-04
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9927 - binary_io_u: 0.9851 - loss: 0.0028 - precision: 0.9975 - recall: 0.9699 - val_accuracy: 0.9834 - val_binary_io_u: 0.9526 - val_loss: 0.0073 - val_precision: 0.9592 - val_recall: 0.9624 - learning_rate: 5.0000e-04
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.9932 - binary_io_u: 0.9873 - loss: 0.0027 - precision: 0.9982 - recall: 0.9712 - val_accuracy: 0.9829 - val_binary_io_u: 0.9511 - val_loss: 0.0076 - val_precision: 0.9582 - val_recall: 0.9608 - learning_rate: 5.0000e-04
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9935 - binary_io_u: 0.9879 - loss: 0.0026 - precision: 0.9984 - recall: 0.9729 - val_accuracy: 0.9834 - val_binary_io_u: 0.9526 - val_loss: 0.0075 - val_precision: 0.9584 - val_recall: 0.9635 - learning_rate: 5.0000e-04
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9936 - binary_io_u: 0.9886 - loss: 0.0025 - precision: 0.9987 - recall: 0.9730 - val_accuracy: 0.9831 - val_binary_io_u: 0.9516 - val_loss: 0.0075 - val_precision: 0.9587 - val_recall: 0.9617 - learning_rate: 2.5000e-04
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9937 - binary_io_u: 0.9887 - loss: 0.0025 - precision: 0.9987 - recall: 0.9731 - val_accuracy: 0.9830 - val_binary_io_u: 0.9512 - val_loss: 0.0076 - val_precision: 0.9571 - val_recall: 0.9623 - learning_rate: 2.5000e-04
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9939 - binary_io_u: 0.9895 - loss: 0.0024 - precision: 0.9989 - recall: 0.9746 - val_accuracy: 0.9830 - val_binary_io_u: 0.9512 - val_loss: 0.0076 - val_precision: 0.9565 - val_recall: 0.9632 - learning_rate: 2.5000e-04
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9941 - binary_io_u: 0.9898 - loss: 0.0024 - precision: 0.9988 - recall: 0.9756 - val_accuracy: 0.9830 - val_binary_io_u: 0.9513 - val_loss: 0.0075 - val_precision: 0.9585 - val_recall: 0.9609 - learning_rate: 2.5000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Train the model for
# Plotting training accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

def visualize_results(image_path, mask_path, model, image_size=(128, 128)):
    # Load and preprocess image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, image_size)
    image_normalized = image.astype('float32') / 255.0

    # Load and preprocess mask
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, image_size)
    mask_normalized = mask.astype('float32') / 255.0

    # Make prediction
    input_image = np.expand_dims(image_normalized, axis=[0, -1])
    prediction = model.predict(input_image)
    prediction = prediction[0, :, :, 0]

    # Create figure with subplots
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    # Plot original image
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title('Original Image')
    axes[0].axis('off')

    # Plot true mask
    axes[1].imshow(mask, cmap='gray')
    axes[1].set_title('True Mask')
    axes[1].axis('off')

    # Plot prediction
    axes[2].imshow(prediction, cmap='gray')
    axes[2].set_title('Prediction')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()

# Usage example:
sample_image_path = "/content/dataset/V2/Imagespng/scene00022.png"
sample_mask_path = "/content/dataset/V2/AnnotationsWB/scene00022.png"
visualize_results(sample_image_path, sample_mask_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
def debug_prediction(image_path, mask_path, model):
    # 1. Load and check image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    print(f"Original image shape: {image.shape}")
    print(f"Original image range: [{image.min()}, {image.max()}]")

    # 2. Preprocess and check
    input_image = cv2.resize(image, (128, 128))
    input_image = input_image.astype('float32') / 255.0
    input_image = np.expand_dims(input_image, axis=[0, -1])
    print(f"Input shape to model: {input_image.shape}")
    print(f"Input range to model: [{input_image.min():.3f}, {input_image.max():.3f}]")

    # 3. Get raw predictions
    raw_pred = model.predict(input_image)
    print(f"Raw prediction shape: {raw_pred.shape}")
    print(f"Raw prediction range: [{raw_pred.min():.3f}, {raw_pred.max():.3f}]")
    print(f"Raw prediction unique values: {np.unique(raw_pred).shape[0]} values")

    # 4. Visualize with detailed information
    plt.figure(figsize=(20, 4))

    plt.subplot(141)
    plt.imshow(image, cmap='gray')
    plt.title('Original')
    plt.colorbar()

    plt.subplot(142)
    plt.imshow(input_image[0,:,:,0], cmap='gray')
    plt.title('Preprocessed')
    plt.colorbar()

    plt.subplot(143)
    plt.imshow(raw_pred[0,:,:,0], cmap='gray')
    plt.title('Raw Prediction')
    plt.colorbar()

    plt.subplot(144)
    binary_pred = (raw_pred[0,:,:,0] > 0.5).astype(np.uint8)
    plt.imshow(binary_pred, cmap='gray')
    plt.title('Binary Prediction')
    plt.colorbar()

    plt.tight_layout()
    plt.show()

    return raw_pred

# Test with a sample image
sample_pred = debug_prediction(sample_image_path, sample_mask_path, model)
# Out:
# Original image shape: (480, 712)
# Original image range: [0, 147]
# Input shape to model: (1, 128, 128, 1)
# Input range to model: [0.000, 0.553]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Raw prediction shape: (1, 128, 128, 1)
# Raw prediction range: [0.103, 0.889]
# Raw prediction unique values: 8981 values

# %%
def detailed_debug(image_path, mask_path, model):
    # Load image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        raise ValueError(f"Failed to load image from {image_path}")
    print(f"1. Original image stats:")
    print(f"   Shape: {image.shape}")
    print(f"   Range: [{image.min()}, {image.max()}]")

    # Preprocess
    resized = cv2.resize(image, (128, 128))
    normalized = resized.astype('float32') / 255.0
    input_tensor = np.expand_dims(normalized, axis=[0, -1])
    print(f"\n2. Input tensor stats:")
    print(f"   Shape: {input_tensor.shape}")
    print(f"   Range: [{input_tensor.min():.3f}, {input_tensor.max():.3f}]")

    # Model prediction
    pred = model.predict(input_tensor)
    print(f"\n3. Raw prediction stats:")
    print(f"   Shape: {pred.shape}")
    print(f"   Range: [{pred.min():.3f}, {pred.max():.3f}]")
    print(f"   Mean: {pred.mean():.3f}")

    # Model summary
    print("\n4. Model architecture:")
    model.summary()

    # Visualize
    fig, axes = plt.subplots(2, 2, figsize=(12, 12))

    axes[0,0].imshow(image, cmap='gray')
    axes[0,0].set_title('1. Original')

    axes[0,1].imshow(normalized, cmap='gray')
    axes[0,1].set_title('2. Normalized Input')

    axes[1,0].imshow(pred[0,:,:,0], cmap='gray')
    axes[1,0].set_title('3. Raw Prediction')

    binary = (pred[0,:,:,0] > 0.5).astype(np.uint8)
    axes[1,1].imshow(binary, cmap='gray')
    axes[1,1].set_title('4. Thresholded')

    plt.tight_layout()
    plt.show()

    return pred, binary

# Run debug
test_pred, test_binary = detailed_debug(sample_image_path, sample_mask_path, model)
# Out:
# 1. Original image stats:
#    Shape: (480, 712)
#    Range: [0, 147]
#
# 2. Input tensor stats:
#    Shape: (1, 128, 128, 1)
#    Range: [0.000, 0.553]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 3. Raw prediction stats:
#    Shape: (1, 128, 128, 1)
#    Range: [0.103, 0.889]
#    Mean: 0.245
#
# 4. Model architecture:
# Model: "lightweight_unet_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 128, 128, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_down0_0  │ (None, 128, 128, 2)    │             18 │ input_layer[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_down0_0… │ (None, 128, 128, 2)    │              8 │ lightweight_unet_down… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_down0_0… │ (None, 128, 128, 2)    │              0 │ lightweight_unet_down… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_

# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 8)      │          1,152 │ lightweight_unet_up1_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 8)      │             32 │ lightweight_unet_up1_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 8)      │              0 │ lightweight_unet_up1_… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 16)     │              0 │ lightweight_unet_up1_… │
# │ (Concatenate)             │                        │                │ lightweight_unet_down… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 8)      │          1,152 │ lightweight_unet_up1_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 8)      │             32 │ lightweight_unet_up1_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up1_con… │ (None, 32, 32, 8)      │              0 │ lightweight_unet_up1_… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_dec… │ (None, 64, 64, 8)      │              0 │ lightweight_unet_up1_… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 4)      │            288 │ lightweight_unet_up2_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 4)      │             16 │ lightweight_unet_up2_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 4)      │              0 │ lightweight_unet_up2_… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 8)      │              0 │ lightweight_unet_up2_… │
# │ (Concatenate)             │                        │                │ lightweight_unet_down… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 4)      │            288 │ lightweight_unet_up2_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 4)      │             16 │ lightweight_unet_up2_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up2_con… │ (None, 64, 64, 4)      │              0 │ lightweight_unet_up2_… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_dec… │ (None, 128, 128, 4)    │              0 │ lightweight_unet_up2_… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 2)    │             72 │ lightweight_unet_up3_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 2)    │              8 │ lightweight_unet_up3_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 2)    │              0 │ lightweight_unet_up3_… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 4)    │              0 │ lightweight_unet_up3_… │
# │ (Concatenate)             │                        │                │ lightweight_unet_down… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 2)    │             72 │ lightweight_unet_up3_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 2)    │              8 │ lightweight_unet_up3_… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_up3_con… │ (None, 128, 128, 2)    │              0 │ lightweight_unet_up3_… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_output   │ (None, 128, 128, 1)    │              3 │ lightweight_unet_up3_… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lightweight_unet_output_… │ (None, 128, 128, 1)    │              0 │ lightweight_unet_outp… │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 93,445 (365.02 KB)
#  Trainable params: 31,025 (121.19 KB)
#  Non-trainable params: 368 (1.44 KB)
#  Optimizer params: 62,052 (242.39 KB)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.metrics import accuracy_score, f1_score

def load_and_preprocess_image(image_path, target_size=(128, 128)):
    original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if original_image is None:
        raise ValueError(f"Could not load image from {image_path}")
    original_image = cv2.resize(original_image, target_size)

    # Debug print
    print(f"Original image range: [{original_image.min()}, {original_image.max()}]")

    preprocessed_image = original_image.astype('float32') / 255.0
    print(f"Preprocessed image range: [{preprocessed_image.min()}, {preprocessed_image.max()}]")

    preprocessed_image = np.expand_dims(preprocessed_image, axis=-1)
    return original_image, preprocessed_image

def load_ground_truth_mask(mask_path, target_size=(128, 128)):
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not load mask from {mask_path}")
    mask = cv2.resize(mask, target_size)
    mask = mask.astype('float32') / 255.0
    print(f"Ground truth mask range: [{mask.min()}, {mask.max()}]")
    return mask

# Load and predict
image_path = "/content/dataset/V3/Imagespng/scene00003.png"
mask_path = "/content/dataset/V3/AnnotationsWB/scene00003.png"

original_image, preprocessed_image = load_and_preprocess_image(image_path)
ground_truth_mask = load_ground_truth_mask(mask_path)

preprocessed_image_batch = np.expand_dims(preprocessed_image, axis=0)
print(f"Input batch shape: {preprocessed_image_batch.shape}")

# Make prediction
predicted_mask = model.predict(preprocessed_image_batch)
print(f"Raw prediction range: [{predicted_mask.min()}, {predicted_mask.max()}]")

# Try different threshold values if needed
threshold = 0.5
predicted_mask_binary = (predicted_mask > threshold).astype(np.uint8)
print(f"Binary prediction unique values: {np.unique(predicted_mask_binary)}")

# Visualization with enhanced contrast
plt.figure(figsize=(15, 5))

plt.subplot(131)
plt.imshow(original_image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(132)
plt.imshow(ground_truth_mask, cmap='gray')
plt.title('Ground Truth Mask')
plt.axis('off')

plt.subplot(133)
plt.imshow(predicted_mask[0, :, :, 0], cmap='gray')
plt.title(f'Predicted Mask (Raw)\nRange: [{predicted_mask.min():.3f}, {predicted_mask.max():.3f}]')
plt.axis('off')

plt.tight_layout()
plt.show()

# Metrics
predicted_flat = predicted_mask_binary[0, :, :, 0].flatten()
ground_truth_flat = (ground_truth_mask > 0.5).astype(np.uint8).flatten()

accuracy = accuracy_score(ground_truth_flat, predicted_flat)
f1 = f1_score(ground_truth_flat, predicted_flat)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Original image range: [0, 159]
# Preprocessed image range: [0.0, 0.6235294342041016]
# Ground truth mask range: [0.0, 1.0]
# Input batch shape: (1, 128, 128, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Raw prediction range: [0.09653235971927643, 0.920856237411499]
# Binary prediction unique values: [0 1]
# Accuracy: 0.9938
# F1 Score: 0.9839

# %% [markdown]
# Model Metrics

# %%
import os
import numpy as np
import cv2
from sklearn.metrics import jaccard_score, f1_score
import matplotlib.pyplot as plt

class TestDataGenerator:
    def __init__(self, image_folder, mask_folder, image_size=(128,128)):
        self.image_paths = sorted([os.path.join(image_folder, f) for f in os.listdir(image_folder)])
        self.mask_paths = sorted([os.path.join(mask_folder, f) for f in os.listdir(mask_folder)])
        self.image_size = image_size

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        # Load and preprocess image
        img_path = self.image_paths[index]
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, self.image_size)
        img = img.astype(np.float32) / 255.0
        img = np.expand_dims(img, axis=-1)

        # Load and preprocess mask
        mask_path = self.mask_paths[index]
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, self.image_size)
        mask = (mask > 127).astype(np.float32)
        mask = np.expand_dims(mask, axis=-1)

        return np.expand_dims(img, axis=0), np.expand_dims(mask, axis=0)

def compute_metrics_with_visualization(model, data_gen, save_path=None):
    iou_scores = []
    dice_scores = []

    for i in range(len(data_gen)):
        print(f"Processing image {i+1}/{len(data_gen)}")

        image, mask = data_gen[i]
        pred = model.predict(image)
        pred_binary = (pred > 0.5).astype(np.uint8)
        mask_binary = (mask > 0.5).astype(np.uint8)

        # Calculate metrics
        iou = jaccard_score(mask_binary.flatten(), pred_binary.flatten())
        dice = f1_score(mask_binary.flatten(), pred_binary.flatten())

        iou_scores.append(iou)
        dice_scores.append(dice)

        # Visualize every 5th image
        if i % 5 == 0:
            plt.figure(figsize=(15, 5))
            plt.subplot(131)
            plt.imshow(image[0,:,:,0], cmap='gray')
            plt.title('Input Image')
            plt.subplot(132)
            plt.imshow(mask[0,:,:,0], cmap='gray')
            plt.title('Ground Truth')
            plt.subplot(133)
            plt.imshow(pred_binary[0,:,:,0], cmap='gray')
            plt.title(f'Prediction\nIoU: {iou:.3f}, Dice: {dice:.3f}')
            plt.tight_layout()
            plt.show()

    mean_iou = np.mean(iou_scores)
    mean_dice = np.mean(dice_scores)
    std_iou = np.std(iou_scores)
    std_dice = np.std(dice_scores)

    return {
        'mean_iou': mean_iou,
        'mean_dice': mean_dice,
        'std_iou': std_iou,
        'std_dice': std_dice,
        'all_ious': iou_scores,
        'all_dices': dice_scores
    }

# Usage
TEST_IMAGE_PATH = "/content/dataset/V2/Images"
TEST_MASK_PATH = "/content/dataset/V2/AnnotationsWB"

test_data_gen = TestDataGenerator(TEST_IMAGE_PATH, TEST_MASK_PATH)
metrics = compute_metrics_with_visualization(model, test_data_gen, save_path='test_predictions')

print(f"Test Results:")
print(f"Mean IoU: {metrics['mean_iou']:.4f} ± {metrics['std_iou']:.4f}")
print(f"Mean Dice: {metrics['mean_dice']:.4f} ± {metrics['std_dice']:.4f}")
# Out:
# Processing image 1/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 2/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 3/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Processing image 4/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Processing image 5/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 6/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 7/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 8/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 9/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 10/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 11/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 12/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing image 13/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 14/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 15/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 16/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 17/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 18/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 19/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 20/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 21/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 22/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 23/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 24/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 25/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Processing image 26/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 27/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 28/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 29/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 30/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing image 31/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 32/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 33/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 34/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing image 35/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 36/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Processing image 37/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 38/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 39/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 40/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 41/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing image 42/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 43/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Processing image 44/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 45/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 46/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 47/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 48/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 49/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 50/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 51/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 52/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 53/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Processing image 54/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 55/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 56/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 57/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 58/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 59/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 60/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 61/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 62/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 63/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Processing image 64/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 65/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 66/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 67/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 68/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 69/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 70/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Processing image 71/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Processing image 72/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 73/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 74/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 75/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 76/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Processing image 77/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Processing image 78/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 79/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 80/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 81/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Processing image 82/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 83/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 84/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Processing image 85/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 86/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Processing image 87/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 88/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 89/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing image 90/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Processing image 91/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Processing image 92/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 93/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 94/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Processing image 95/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 96/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Processing image 97/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 98/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 99/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 100/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 101/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 102/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 103/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 104/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 105/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 106/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 107/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 108/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 109/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 110/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 111/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Processing image 112/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 113/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 114/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 115/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 116/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Processing image 117/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 118/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 119/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 120/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 121/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 122/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 123/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Processing image 124/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 125/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 126/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 127/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 128/128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Test Results:
# Mean IoU: 0.5833 ± 0.0457
# Mean Dice: 0.7357 ± 0.0366
